# %% [markdown]
# 1. selesaikan soal berikut

# %%
import numpy as np

# %%
vektor = np.array([[25],[2],[-3],[-23]])

# %%
vektor_transpose = vektor.T

# %%
print("Vektor awal:\n", vektor)
print("Transpose:\n", vektor_transpose)
# Out:
# Vektor awal:
#  [[ 25]
#  [  2]
#  [ -3]
#  [-23]]
# Transpose:
#  [[ 25   2  -3 -23]]
