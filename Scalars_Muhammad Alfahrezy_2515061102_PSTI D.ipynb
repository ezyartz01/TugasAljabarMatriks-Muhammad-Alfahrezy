# %% [markdown]
# 1. buat variabel skalar x dan simpan suatu nilai skalar

# %%
x = 25
x
# Out:
# 25

# %% [markdown]
# tampilkan tipe data dari x

# %%
print(x)
# Out:
# 25

# %% [markdown]
# buat variabel skalar y dan simpan suatu nilai skalar

# %%
y = 102

# %% [markdown]
# tampilkan tipe data dari y

# %%
print(y)
# Out:
# 102

# %% [markdown]
# jumlahkan x+y

# %%
x + y
# Out:
# 127

# %% [markdown]
# buat variabel bernama x_float dan simpan suatu nilai desimal

# %%
x_float = 30

# %% [markdown]
# jumlahkan x_float dengan y

# %%
x_float + y
# Out:
# 132

# %% [markdown]
# tampilkan tipe data dari x_float

# %%
print(x_float)
# Out:
# 30

# %% [markdown]
# 2. lakukan tahapan pada soal 1 dengan menggunakan tensorflow

# %%
import tensorflow as tf

# %%
x_tf = tf.Variable(25.0)

# %%
print(x_tf)
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=25.0>

# %%
y_tf = tf.Variable(0.25)

# %%
print(y_tf)
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.25>

# %%
x_tf + y_tf
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=25.25>

# %%
tf_float = tf.Variable(30.0)

# %%
tf_float + y_tf
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=30.25>

# %%
print(tf_float)
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=30.0>

# %% [markdown]
# 3. lakukan tahapan pada soal 1 dengan menggunakan pytorch

# %%
import torch

# %%
x_pt = torch.tensor(25.0)

# %%
print(x_pt)
# Out:
# tensor(25.)

# %%
y_pt = torch.tensor(0.25)

# %%
print(y_pt)
# Out:
# tensor(0.2500)

# %%
x_pt + y_pt
# Out:
# tensor(25.2500)

# %%
pt_float = torch.tensor(30.0)

# %%
pt_float + y_pt
# Out:
# tensor(30.2500)

# %%
print(pt_float)
# Out:
# tensor(30.)
